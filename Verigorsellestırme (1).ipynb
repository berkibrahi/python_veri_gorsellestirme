# %%
import seaborn as sns
import pandas as pd

# %%
planets=sns.load_dataset("planets")
df=planets.copy()
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %% [markdown]
# # sadece katogerik değişkenler ve özetleri

# %%
kat_df=df.select_dtypes(include=["object"])
kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %% [markdown]
# # katogerik değişkenlerin sınıflarına ve sınıf sayısına erişmek

# %%
kat_df.method.unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
kat_df["method"].value_counts().count()
# Out:
# 10

# %% [markdown]
# # katogerik değişkenlerin sınıflarının frekanslarına erişmek

# %%
kat_df["method"].value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
kat_df["method"].value_counts().plot.barh();

# %% [markdown]
# # sürekli değişken özetleri

# %%
num_df=df.select_dtypes(include=["float64","int64"])
num_df.head()
# Out:
#    number  orbital_period   mass  distance  year
# 0       1         269.300   7.10     77.40  2006
# 1       1         874.774   2.21     56.95  2008
# 2       1         763.000   2.60     19.84  2011
# 3       1         326.030  19.40    110.62  2007
# 4       1         516.220  10.50    119.47  2009

# %% [markdown]
# # dağılım grafikleri

# %%
diamonds=sns.load_dataset("diamonds")
df_diamons=diamonds.copy()
df_diamons.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # veri setine hızlı bakış

# %%
df_diamons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# ordinal tanımlama

# %%
from pandas.api.types import CategoricalDtype

# %%
cut_kategoriler=["fair","good","very good","premium","ideal"]

# %%
#df_diamons.cut=df_diamons.cut.astype(CategoricalDtype(categories=cut_kategoriler,ordered=True))
#df_diamons.cut.head()

# %% [markdown]
# # barplot

# %%
kat_df_diamonds=df_diamons.select_dtypes(include=["category"])
kat_df_diamonds
# Out:
#        cut color clarity
# 0      NaN     E     SI2
# 1      NaN     E     SI1
# 2      NaN     E     VS1
# 3      NaN     I     VS2
# 4      NaN     J     SI2
# ...    ...   ...     ...
# 53935  NaN     D     SI1
# 53936  NaN     D     SI1
# 53937  NaN     D     SI1
# 53938  NaN     H     SI2
# 53939  NaN     D     SI2
#
# [53940 rows x 3 columns]

# %%
(kat_df_diamonds["cut"]
 .value_counts()
 )
# Out:
# fair         0
# good         0
# very good    0
# premium      0
# ideal        0
# Name: cut, dtype: int64

# %%
(kat_df_diamonds["cut"]
 .value_counts().
 plot.barh()
 .set_title("cut değişkeninin sınıf frekansları"));

# %%
kat_df["method"].value_counts().plot.barh();

# %%
sns.barplot(x="method" , y=kat_df.method.index ,data=kat_df);

# %%
sns.catplot(x="cut" , y="price" ,data=df_diamons);

# %% [markdown]
# dğrusal ilşkinin gözterilmesi

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
tips=sns.load_dataset("tips")
df_tips=tips.copy()
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x="total_bill", y="tip",data=df_tips)

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker",data=df_tips)

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker",col="time",data=df_tips)

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker",col="time",row="sex",data=df_tips)

# %% [markdown]
# scatterplot matrisi

# %%
iris=sns.load_dataset("iris")
df_iris=iris.copy()
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df_iris);

# %%
sns.pairplot(df_iris,hue= "species");

# %%
sns.pairplot(df_iris,kind= "reg");

# %%
sns.pairplot(df_iris,kind= "reg",hue="species");

# %% [markdown]
# çizgi grafik

# %%
fmri=sns.load_dataset("fmri")
df_fmri=fmri.copy()
df_fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# çizgi grafik ve çaprazlamalar

# %%
sns.lineplot(x="timepoint",y="signal",data=df_fmri);

# %%
sns.lineplot(x="timepoint",y="signal",data=df_fmri,hue="event");

# %%
sns.lineplot(x="timepoint",y="signal"
,style="event"
,markers=True
,dashes=False
,data=df_fmri,hue="event"
);
